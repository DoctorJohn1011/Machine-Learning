# %%
# %matplotlib notebook
import numpy as np
from numpy.linalg import *
import scipy.io as sio
import matplotlib.pyplot as plt

# %%
def Kmeans(k, x, max_step=1000 ):
    M,D = x.shape
    
    # initialization
    yu = np.arange( M )
    np.random.shuffle( yu )
    mu = x[ yu[:k],: ]
    old_mu = np.zeros_like( mu )
    index = np.arange( M )
    C = [x for x in range(k)]
    step = 0
    
    while( step<max_step and np.abs(old_mu-mu).sum()>0 ):
        step += 1
        old_mu = mu
        dist = np.zeros( (k,M) )
        for i in range(k):
            x_mu = x - mu[i,:]
            dist[i,:] = np.diag( np.dot( x_mu , x_mu.T ) )
        yu = dist.argmin(0)

        for i in range(k):
            C[i] = index[yu==i]
            mu[i,:] = x[C[i],:].mean(0)
    print(step)
    return mu,C

# %%
#np.random.seed(15)
patch_size = 200
key = np.array([[0.0,1.0,6.0,7.0],[3.0,9.0,4.0,10.0]])
key = np.row_stack( (key,np.random.normal(size=(8,4))) )
print(key)
std = np.array([1,1,1,1])
data =  key[:,0:1] + np.random.normal(size=(10,patch_size))*std[0]
for i in range(1,4):
    data = np.column_stack( (data , key[:,i:i+1] + np.random.normal(size=(10,patch_size))*std[i] ) )
data = data.T

label = np.array([[1,2,3,4]])
label = np.dot( label.T , np.ones( (1,patch_size) ) ).reshape(1,-1).T
# Out:
# [[  0.           1.           6.           7.        ]
#  [  3.           9.           4.          10.        ]
#  [  1.19715419  -0.24863067  -0.64265522  -1.11440675]
#  [ -0.71376862   1.16080388  -0.43088192   1.25274464]
#  [ -0.21314835  -0.30304123  -1.12897742   0.40475751]
#  [ -0.26880661   1.23234341   0.64477092  -0.12813177]
#  [ -0.99401417  -0.03214849   1.31754281   0.38990053]
#  [  0.16008293   0.75855241  -0.86877918   0.89045806]
#  [ -0.71707373  -2.22168071  -2.27734817   0.23336352]
#  [ -0.15434131   0.55479712  -0.47640696  -1.21130062]]

# %%
mu,_ = Kmeans( 4, data )

# %%
plt.scatter( data[:,0],data[:,1], c=label )
plt.scatter(mu[:,0],mu[:,1],c='r')
plt.ion()
# Out:
# <img src="data:image/png;base64,..." width="640">
